# %% [markdown]
# # Imports and Load Data

# %%
import numpy as np  # linear algebra
import pandas as pd # data processing, like text ,CSV or pdf file

df = pd.read_csv(r'C:\\Users\\AR 161\\Desktop\\Final Project\\Data Set\\kindle_reviews.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-959d0d58b5c8> in <module>
#       2 import pandas as pd # data processing, like text ,CSV or pdf file
#       3
# ----> 4 df = pd.read_csv(r'C:\\Users\\AR 161\\Desktop\\Final Project\\Data Set\\kindle_reviews.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     with parser:
# --> 463         return parser.read(nrows)
#     464
#     465
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1050     def read(self, nrows=None):
#    1051         nrows = validate_integer("nrows", nrows)
# -> 1052         index, columns, col_dict = self._engine.read(nrows)
#    1053
#    1054         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2054     def read(self, nrows=None):
#    2055         try:
# -> 2056             data = self._reader.read(nrows)
#    2057         except StopIteration:
#    2058             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 8, saw 2

# %%
df.head(10)   # here i check data by using head function also we pass perameter in integer value
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  B000F83SZQ  [0, 0]        5
# 1           1  B000F83SZQ  [2, 2]        4
# 2           2  B000F83SZQ  [2, 2]        4
# 3           3  B000F83SZQ  [1, 1]        5
# 4           4  B000F83SZQ  [0, 1]        4
# 5           5  B000F83SZQ  [0, 0]        4
# 6           6  B000F83SZQ  [0, 0]        4
# 7           7  B000F83SZQ  [1, 1]        4
# 8           8  B000FA64PA  [0, 0]        5
# 9           9  B000FA64PA  [0, 0]        4
#
#                                           reviewText   reviewTime  \
# 0  I enjoy vintage books and movies so I enjoyed ...   05 5, 2014
# 1  This book is a reissue of an old one; the auth...   01 6, 2014
# 2  This was a fairly interesting read.  It had ol...   04 4, 2014
# 3  I'd never read any of the Amy Brewster mysteri...  02 19, 2014
# 4  If you like period pieces - clothing, lingo, y...  03 19, 2014
# 5  A beautiful in-depth character description mak...  05 26, 2014
# 6  I enjoyed this one tho I'm not sure why it's c...  06 10, 2014
# 7  Never heard of Amy Brewster. But I don't need ...  03 22, 2014
# 8  Darth Maul working under cloak of darkness com...  10 11, 2013
# 9  This is a short story focused on Darth Maul's ...  02 13, 2011
#
#        reviewerID                         reviewerName  \
# 0  A1F6404F1VG29J                           Avidreader
# 1   AN0N05A9LIJEQ                             critters
# 2   A795DMNCJILA6                                  dot
# 3  A1FV0SX13TWVXQ  Elaine H. Turley "Montana Songbird"
# 4  A3SPTOKDG7WBLN                   Father Dowling Fan
# 5  A1RK2OCZDSGC6R                     ubavka seirovska
# 6  A2HSAKHC3IBRE6                             Wolfmist
# 7  A3DE6XGZ2EPADS                                  WPY
# 8  A1UG4Q4D3OAH3A                                  dsa
# 9   AQZH7YTWQPOBE                             Enjolras
#
#                                          summary  unixReviewTime
# 0                             Nice vintage story      1399248000
# 1                                   Different...      1388966400
# 2                                          Oldie      1396569600
# 3                             I really liked it.      1392768000
# 4                                 Period Mystery      1395187200
# 5                                         Review      1401062400
# 6                       Nice old fashioned story      1402358400
# 7  Enjoyable reading and reminding the old times      1395446400
# 8                                     Darth Maul      1381449600
# 9                       Not bad, not exceptional      1297555200

# %%
len(df)   # here i check the lenght
# Out:
# 982619

# %%
df.isnull().sum()   # for missing value
# Out:
# Unnamed: 0           0
# asin                 0
# helpful              0
# overall              0
# reviewText          22
# reviewTime           0
# reviewerID           0
# reviewerName      3816
# summary              1
# unixReviewTime       0
# dtype: int64

# %%
#drop the rows where there are no reviews
df.dropna(subset = ['reviewText'], inplace = True)

#changing the reviewTime column to be of datetime type
df.reviewTime = pd.to_datetime(df.reviewTime)

#creating a column with just the year so in this way we can also easily find review of each years
df['Year'] = df.reviewTime.dt.year

#show 7 top value of each row 
df.head(7)
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  B000F83SZQ  [0, 0]        5
# 1           1  B000F83SZQ  [2, 2]        4
# 2           2  B000F83SZQ  [2, 2]        4
# 3           3  B000F83SZQ  [1, 1]        5
# 4           4  B000F83SZQ  [0, 1]        4
# 5           5  B000F83SZQ  [0, 0]        4
# 6           6  B000F83SZQ  [0, 0]        4
#
#                                           reviewText reviewTime  \
# 0  I enjoy vintage books and movies so I enjoyed ... 2014-05-05
# 1  This book is a reissue of an old one; the auth... 2014-01-06
# 2  This was a fairly interesting read.  It had ol... 2014-04-04
# 3  I'd never read any of the Amy Brewster mysteri... 2014-02-19
# 4  If you like period pieces - clothing, lingo, y... 2014-03-19
# 5  A beautiful in-depth character description mak... 2014-05-26
# 6  I enjoyed this one tho I'm not sure why it's c... 2014-06-10
#
#        reviewerID                         reviewerName  \
# 0  A1F6404F1VG29J                           Avidreader
# 1   AN0N05A9LIJEQ                             critters
# 2   A795DMNCJILA6                                  dot
# 3  A1FV0SX13TWVXQ  Elaine H. Turley "Montana Songbird"
# 4  A3SPTOKDG7WBLN                   Father Dowling Fan
# 5  A1RK2OCZDSGC6R                     ubavka seirovska
# 6  A2HSAKHC3IBRE6                             Wolfmist
#
#                     summary  unixReviewTime  Year
# 0        Nice vintage story      1399248000  2014
# 1              Different...      1388966400  2014
# 2                     Oldie      1396569600  2014
# 3        I really liked it.      1392768000  2014
# 4            Period Mystery      1395187200  2014
# 5                    Review      1401062400  2014
# 6  Nice old fashioned story      1402358400  2014

# %% [markdown]
# # Analyse data with graphically representation

# %%
import matplotlib.pyplot as plt  # for graphically representation 
df.Year.value_counts().sort_index().plot(kind = 'bar')  
plt.title('Number of Reviews per Year')
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
plt.show()

# %%
df.overall.value_counts().plot(kind = 'bar')
plt.title('Number of Good Ratings vs Bad Ratings')
plt.xlabel('Rating Scales')
plt.xticks(rotation = 0)
plt.ylabel('Total ratings')
plt.show()

# %% [markdown]
# # Text Preprocessing

# %%
df.head(10)
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  B000F83SZQ  [0, 0]        5
# 1           1  B000F83SZQ  [2, 2]        4
# 2           2  B000F83SZQ  [2, 2]        4
# 3           3  B000F83SZQ  [1, 1]        5
# 4           4  B000F83SZQ  [0, 1]        4
# 5           5  B000F83SZQ  [0, 0]        4
# 6           6  B000F83SZQ  [0, 0]        4
# 7           7  B000F83SZQ  [1, 1]        4
# 8           8  B000FA64PA  [0, 0]        5
# 9           9  B000FA64PA  [0, 0]        4
#
#                                           reviewText reviewTime  \
# 0  I enjoy vintage books and movies so I enjoyed ... 2014-05-05
# 1  This book is a reissue of an old one; the auth... 2014-01-06
# 2  This was a fairly interesting read.  It had ol... 2014-04-04
# 3  I'd never read any of the Amy Brewster mysteri... 2014-02-19
# 4  If you like period pieces - clothing, lingo, y... 2014-03-19
# 5  A beautiful in-depth character description mak... 2014-05-26
# 6  I enjoyed this one tho I'm not sure why it's c... 2014-06-10
# 7  Never heard of Amy Brewster. But I don't need ... 2014-03-22
# 8  Darth Maul working under cloak of darkness com... 2013-10-11
# 9  This is a short story focused on Darth Maul's ... 2011-02-13
#
#        reviewerID                         reviewerName  \
# 0  A1F6404F1VG29J                           Avidreader
# 1   AN0N05A9LIJEQ                             critters
# 2   A795DMNCJILA6                                  dot
# 3  A1FV0SX13TWVXQ  Elaine H. Turley "Montana Songbird"
# 4  A3SPTOKDG7WBLN                   Father Dowling Fan
# 5  A1RK2OCZDSGC6R                     ubavka seirovska
# 6  A2HSAKHC3IBRE6                             Wolfmist
# 7  A3DE6XGZ2EPADS                                  WPY
# 8  A1UG4Q4D3OAH3A                                  dsa
# 9   AQZH7YTWQPOBE                             Enjolras
#
#                                          summary  unixReviewTime  Year
# 0                             Nice vintage story      1399248000  2014
# 1                                   Different...      1388966400  2014
# 2                                          Oldie      1396569600  2014
# 3                             I really liked it.      1392768000  2014
# 4                                 Period Mystery      1395187200  2014
# 5                                         Review      1401062400  2014
# 6                       Nice old fashioned story      1402358400  2014
# 7  Enjoyable reading and reminding the old times      1395446400  2014
# 8                                     Darth Maul      1381449600  2013
# 9                       Not bad, not exceptional      1297555200  2011

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 982597 entries, 0 to 982618
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      982597 non-null  int64
#  1   asin            982597 non-null  object
#  2   helpful         982597 non-null  object
#  3   overall         982597 non-null  int64
#  4   reviewText      982597 non-null  object
#  5   reviewTime      982597 non-null  datetime64[ns]
#  6   reviewerID      982597 non-null  object
#  7   reviewerName    978781 non-null  object
#  8   summary         982596 non-null  object
#  9   unixReviewTime  982597 non-null  int64
#  10  Year            982597 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 90.0+ MB

# %%
del df['Year']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 982597 entries, 0 to 982618
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      982597 non-null  int64
#  1   asin            982597 non-null  object
#  2   helpful         982597 non-null  object
#  3   overall         982597 non-null  int64
#  4   reviewText      982597 non-null  object
#  5   reviewTime      982597 non-null  datetime64[ns]
#  6   reviewerID      982597 non-null  object
#  7   reviewerName    978781 non-null  object
#  8   summary         982596 non-null  object
#  9   unixReviewTime  982597 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 82.5+ MB

# %%
df.head(10)
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  B000F83SZQ  [0, 0]        5
# 1           1  B000F83SZQ  [2, 2]        4
# 2           2  B000F83SZQ  [2, 2]        4
# 3           3  B000F83SZQ  [1, 1]        5
# 4           4  B000F83SZQ  [0, 1]        4
# 5           5  B000F83SZQ  [0, 0]        4
# 6           6  B000F83SZQ  [0, 0]        4
# 7           7  B000F83SZQ  [1, 1]        4
# 8           8  B000FA64PA  [0, 0]        5
# 9           9  B000FA64PA  [0, 0]        4
#
#                                           reviewText reviewTime  \
# 0  I enjoy vintage books and movies so I enjoyed ... 2014-05-05
# 1  This book is a reissue of an old one; the auth... 2014-01-06
# 2  This was a fairly interesting read.  It had ol... 2014-04-04
# 3  I'd never read any of the Amy Brewster mysteri... 2014-02-19
# 4  If you like period pieces - clothing, lingo, y... 2014-03-19
# 5  A beautiful in-depth character description mak... 2014-05-26
# 6  I enjoyed this one tho I'm not sure why it's c... 2014-06-10
# 7  Never heard of Amy Brewster. But I don't need ... 2014-03-22
# 8  Darth Maul working under cloak of darkness com... 2013-10-11
# 9  This is a short story focused on Darth Maul's ... 2011-02-13
#
#        reviewerID                         reviewerName  \
# 0  A1F6404F1VG29J                           Avidreader
# 1   AN0N05A9LIJEQ                             critters
# 2   A795DMNCJILA6                                  dot
# 3  A1FV0SX13TWVXQ  Elaine H. Turley "Montana Songbird"
# 4  A3SPTOKDG7WBLN                   Father Dowling Fan
# 5  A1RK2OCZDSGC6R                     ubavka seirovska
# 6  A2HSAKHC3IBRE6                             Wolfmist
# 7  A3DE6XGZ2EPADS                                  WPY
# 8  A1UG4Q4D3OAH3A                                  dsa
# 9   AQZH7YTWQPOBE                             Enjolras
#
#                                          summary  unixReviewTime
# 0                             Nice vintage story      1399248000
# 1                                   Different...      1388966400
# 2                                          Oldie      1396569600
# 3                             I really liked it.      1392768000
# 4                                 Period Mystery      1395187200
# 5                                         Review      1401062400
# 6                       Nice old fashioned story      1402358400
# 7  Enjoyable reading and reminding the old times      1395446400
# 8                                     Darth Maul      1381449600
# 9                       Not bad, not exceptional      1297555200

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# asin                 0
# helpful              0
# overall              0
# reviewText           0
# reviewTime           0
# reviewerID           0
# reviewerName      3816
# summary              1
# unixReviewTime       0
# dtype: int64

# %%
df['reviewText'] = df['reviewText'] + ' ' + df['summary']

# %%
del df['summary']

# %%
df.head(10)
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  B000F83SZQ  [0, 0]        5
# 1           1  B000F83SZQ  [2, 2]        4
# 2           2  B000F83SZQ  [2, 2]        4
# 3           3  B000F83SZQ  [1, 1]        5
# 4           4  B000F83SZQ  [0, 1]        4
# 5           5  B000F83SZQ  [0, 0]        4
# 6           6  B000F83SZQ  [0, 0]        4
# 7           7  B000F83SZQ  [1, 1]        4
# 8           8  B000FA64PA  [0, 0]        5
# 9           9  B000FA64PA  [0, 0]        4
#
#                                           reviewText reviewTime  \
# 0  I enjoy vintage books and movies so I enjoyed ... 2014-05-05
# 1  This book is a reissue of an old one; the auth... 2014-01-06
# 2  This was a fairly interesting read.  It had ol... 2014-04-04
# 3  I'd never read any of the Amy Brewster mysteri... 2014-02-19
# 4  If you like period pieces - clothing, lingo, y... 2014-03-19
# 5  A beautiful in-depth character description mak... 2014-05-26
# 6  I enjoyed this one tho I'm not sure why it's c... 2014-06-10
# 7  Never heard of Amy Brewster. But I don't need ... 2014-03-22
# 8  Darth Maul working under cloak of darkness com... 2013-10-11
# 9  This is a short story focused on Darth Maul's ... 2011-02-13
#
#        reviewerID                         reviewerName  unixReviewTime
# 0  A1F6404F1VG29J                           Avidreader      1399248000
# 1   AN0N05A9LIJEQ                             critters      1388966400
# 2   A795DMNCJILA6                                  dot      1396569600
# 3  A1FV0SX13TWVXQ  Elaine H. Turley "Montana Songbird"      1392768000
# 4  A3SPTOKDG7WBLN                   Father Dowling Fan      1395187200
# 5  A1RK2OCZDSGC6R                     ubavka seirovska      1401062400
# 6  A2HSAKHC3IBRE6                             Wolfmist      1402358400
# 7  A3DE6XGZ2EPADS                                  WPY      1395446400
# 8  A1UG4Q4D3OAH3A                                  dsa      1381449600
# 9   AQZH7YTWQPOBE                             Enjolras      1297555200

# %%
def review_sentiment(rating): 
    # Replacing rating of 1,2,3 with 0(not good) and 4,5 with 1(good) 
    if(rating == 1 or rating == 2 or rating == 3):
        return 0
    else:
        return 1

# %%
df.overall = df.overall.apply(review_sentiment)
df.head()
# Out:
#    Unnamed: 0        asin helpful  overall  \
# 0           0  B000F83SZQ  [0, 0]        1
# 1           1  B000F83SZQ  [2, 2]        1
# 2           2  B000F83SZQ  [2, 2]        1
# 3           3  B000F83SZQ  [1, 1]        1
# 4           4  B000F83SZQ  [0, 1]        1
#
#                                           reviewText reviewTime  \
# 0  I enjoy vintage books and movies so I enjoyed ... 2014-05-05
# 1  This book is a reissue of an old one; the auth... 2014-01-06
# 2  This was a fairly interesting read.  It had ol... 2014-04-04
# 3  I'd never read any of the Amy Brewster mysteri... 2014-02-19
# 4  If you like period pieces - clothing, lingo, y... 2014-03-19
#
#        reviewerID                         reviewerName  unixReviewTime
# 0  A1F6404F1VG29J                           Avidreader      1399248000
# 1   AN0N05A9LIJEQ                             critters      1388966400
# 2   A795DMNCJILA6                                  dot      1396569600
# 3  A1FV0SX13TWVXQ  Elaine H. Turley "Montana Songbird"      1392768000
# 4  A3SPTOKDG7WBLN                   Father Dowling Fan      1395187200

# %%
df.overall.value_counts()
# Out:
# 1    829256
# 0    153341
# Name: overall, dtype: int64

# %%
del df['Unnamed: 0']
del df['asin']
del df['helpful']
del df['reviewTime']
del df['reviewerID']
del df['reviewerName']
del df['unixReviewTime']

# %%
df.isnull().sum() # check missing value
# Out:
# overall       0
# reviewText    1
# dtype: int64

# %%
#drop the rows where there are no reviews
df.dropna(subset = ['reviewText'], inplace = True)

# %%
df.isnull().sum() # here we can see no missing value
# Out:
# overall       0
# reviewText    0
# dtype: int64

# %%
from nltk.corpus import stopwords
import string
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)

# %%
def clean_text(text):  # function for data cleaning 
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop:
            word = i.strip().lower()
            final_text.append(word)
    return " ".join(final_text)

# %% [markdown]
# # feature_extraction

# %%
# Creating the Bag of Words model
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
x_train,x_test,y_train,y_test = train_test_split(df.reviewText,df.overall, random_state = 0)
cv=CountVectorizer(min_df=0,max_df=1,ngram_range=(1,1))
#transformed train reviews
cv_train_reviews=cv.fit_transform(x_train)
#transformed test reviews
cv_test_reviews=cv.transform(x_test)

print('BOW_cv_train:',cv_train_reviews.shape)
print('BOW_cv_test:',cv_test_reviews.shape)
# Out:
# BOW_cv_train: (736947, 135356)
# BOW_cv_test: (245649, 135356)

# %% [markdown]
# #  Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
mnb = LogisticRegression()
mnb.fit(cv_train_reviews,y_train)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
mnb_pred = mnb.predict(cv_test_reviews)
accuracy_score(y_test,mnb_pred)

# %%
cv_report = classification_report(y_test,mnb_pred,target_names = ['0','1'])
print(cv_report)

# %%
cm_cv = confusion_matrix(y_test,mnb_pred)
cm_cv

# %%
cm_cv = pd.DataFrame(cm_cv, index=[0,1], columns=[0,1])
cm_cv.index.name = 'Actual'
cm_cv.columns.name = 'Predicted'

# %% [markdown]
# # Accuracy graphically representation

# %%
cm_cv.plot(kind = 'bar')
plt.title('Model accuracy Good Ratings vs Bad Ratings')
plt.xlabel('Rating Scales')
plt.xticks(rotation = 0)
plt.ylabel('Total ratings')
plt.show()

# %% [markdown]
# # By using Logistic Regression our accuracy_score

# %%
mnb_pred = mnb.predict(cv_test_reviews)
accuracy_score(y_test,mnb_pred)*100

# %% [markdown]
# 78.937808
